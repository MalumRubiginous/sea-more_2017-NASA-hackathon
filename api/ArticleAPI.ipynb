# %%
from flask import request
from flask import Flask
app = Flask(__name__)

@app.route("/article")
def article():
    beach = request.args.get('beach')
    return json.dumps(obj[beach])
    
    
#     return "Hello World!"

if __name__ == "__main__":
    app.run(host='0.0.0.0', port=5001)
# Out:
#  * Running on http://0.0.0.0:5001/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/Apr/2017 05:19:59] "GET /article?beach=%E7%99%BD%E6%B2%99%E7%81%A3%E6%B5%B7%E6%B0%B4%E6%B5%B4%E5%A0%B4 HTTP/1.0" 200 -
# 127.0.0.1 - - [29/Apr/2017 05:21:04] "GET /article?beach=%E7%99%BD%E6%B2%99%E7%81%A3%E6%B5%B7%E6%B0%B4%E6%B5%B4%E5%A0%B4 HTTP/1.0" 200 -
# 127.0.0.1 - - [29/Apr/2017 05:22:50] "GET /article?beach=%E7%99%BD%E6%B2%99%E7%81%A3%E6%B5%B7%E6%B0%B4%E6%B5%B4%E5%A0%B4 HTTP/1.0" 200 -

# %%
import json

# %%
objs = """{
  "沙崙海水浴場" : {
    "beach" : "沙崙海水浴場",
    "article1" : "http://ru1573.pixnet.net/blog/post/27119200",
    "pic" : "http://pic.pimg.tw/ru1573/79d477669a3532c37339e630133401c3.jpg"
  },
  "白沙灣海水浴場" : {
    "beach" : "白沙灣海水浴場",
    "article1" : "http://qpjj.pixnet.net/blog/post/3394374",
    "pic" : "http://pic.pimg.tw/qpjj/3f8857067222935d11d7ffe4d6c2c7a1.jpg?v=1287477513"
  },
  "金沙灣海水浴場" : {
    "beach" : "金沙灣海水浴場",
    "article1" : "http://k640640.pixnet.net/blog/post/8659578",
    "pic" : "http://pic.pimg.tw/k640640/acdcfa48669fcee797dc32f2f4b1c99c.jpg?v=1277141192"
  },
  "翡翠灣海水浴場" : {
    "beach" : "翡翠灣海水浴場",
    "article1" : "http://celery831218.pixnet.net/blog/post/177931027",
    "pic" : "http://pic.pimg.tw/celery831218/1408518344-3047349091_m.jpg"
  },
  "福隆海水浴場" : {
    "beach" : "福隆海水浴場",
    "article1" : "http://puccagaru520.pixnet.net/blog/post/118094092",
    "pic" : "http://pic.pimg.tw/puccagaru520/1371290357-3713255629_m.jpg"
  },
  "大武崙白沙灘" : {
    "beach" : "大武崙白沙灘",
    "article1" : "http://ub874001.pixnet.net/blog/post/450041360",
    "pic" : "https://pic.pimg.tw/ub874001/1468999800-2584973482_n.jpg"
  },
  "外木山海水浴場" : {
    "beach" : "外木山海水浴場",
    "article1" : "http://vunesa.pixnet.net/blog/post/30478888",
    "pic" : "http://pic.pimg.tw/vunesa/f5a8dd58516d8945e1bfa9d295c8e235_m.jpg"
  },
  "竹圍海水浴場" : {
    "beach" : "竹圍海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "觀音海水浴場" : {
    "beach" : "觀音海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "蜜月灣" : {
    "beach" : "蜜月灣",
    "article1" : "",
    "pic" : ""
  },
  "頭城海水浴場" : {
    "beach" : "頭城海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "內埤海水浴場" : {
    "beach" : "內埤海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "通霄海水浴場" : {
    "beach" : "通霄海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "崎頂海水浴場" : {
    "beach" : "崎頂海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "大安海水浴場" : {
    "beach" : "大安海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "三條崙海水浴場" : {
    "beach" : "三條崙海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "馬沙溝海水浴場" : {
    "beach" : "馬沙溝海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "鯤鯓海水浴場" : {
    "beach" : "鯤鯓海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "西子灣海水浴場" : {
    "beach" : "西子灣海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "旗津海水浴場" : {
    "beach" : "旗津海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "南灣海水浴場" : {
    "beach" : "南灣海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "小灣海水浴場" : {
    "beach" : "小灣海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "墾丁海水浴場" : {
    "beach" : "墾丁海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "磯崎海水浴場" : {
    "beach" : "磯崎海水浴場",
    "article1" : "",
    "pic" : ""
  },
  "杉原海水浴場" : {
    "beach" : "杉原海水浴場",
    "article1" : "",
    "pic" : ""
  }
}"""

obj = json.loads(objs)
